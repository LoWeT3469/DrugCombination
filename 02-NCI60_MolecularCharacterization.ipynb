# %% [markdown]
# #### NCI-60 Molecular Characterization from [CellMinerCDB](https://discover.nci.nih.gov/rsconnect/cellminercdb/), include:
#
# - Gene expression:
#     - data_NCI-60_xsq.txt
#     - footnotes_NCI-60_xsq.csv
#     - Cell_line_annotation_nci60.txt
#     - Table_Drugs_Synonyms_cdb.txt
#
# - microRNA expression:
#     - data_NCI-60_mir.txt
#     - footnotes_NCI-60_mir.csv
#     - Cell_line_annotation_nci60.txt
#     - Table_Drugs_Synonyms_cdb.txt
#
# - Protein abundance:
#     - data_NCI-60_swa.txt
#     - footnotes_NCI-60_swa.csv
#     - Cell_line_annotation_nci60.txt
#     - Table_Drugs_Synonyms_cdb.txt

# %%
# Read the Gene expression: data_NCI-60_xsq.txt file

import pandas as pd

# Path to your text file
txt_file_path = "/nfs/turbo/med-kayvan-lab/Projects/DrugCombination/b-DrugCombination/DC_Data/NCI60-GeneExpression/data_NCI-60_xsq.txt"

# Read the text file into a DataFrame
df = pd.read_csv(txt_file_path, delimiter='\t')

# Display the DataFrame
print(df.info())
print(df.head())
# print(df.tail())

# Save the DataFrame to a new CSV file
df.to_csv("NCI60_GeneExpression.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23826 entries, 0 to 23825
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              23826 non-null  object
#  1   chr             23826 non-null  object
#  2   txStart         23826 non-null  int64
#  3   txEnd           23826 non-null  int64
#  4   entrez.gene.id  23804 non-null  float64
#  5   BR:MCF7         23826 non-null  float64
#  6   BR:MDA-MB-231   23826 non-null  float64
#  7   BR:HS 578T      23826 non-null  float64
#  8   BR:BT-549       23826 non-null  float64
#  9   BR:T-47D        23826 non-null  float64
#  10  CNS:SF-268      23826 non-null  float64
#  11  CNS:SF-295      23826 non-null  float64
#  12  CNS:SF-539      23826 non-null  float64
#  13  CNS:SNB-19      23826 non-null  float64
#  14  CNS:SNB-75      23826 non-null  float64
#  15  CNS:U251        23826 non-null  float64
#  16  CO:COLO 205     23826 non-null  float64
#  17  CO:HCC-2998     23826 non-null  float64
#  18  CO:HCT-116      23826 non-null  float64
#  19  CO:HCT-15       23826 non-null  float64
#  20  CO:HT29         23826 non-null  float64
#  21  CO:KM12         23826 non-null  float64
#  22  CO:SW-620       23826 non-null  float64
#  23  LE:CCRF-CEM     23826 non-null  float64
#  24  LE:HL-60(TB)    23826 non-null  float64
#  25  LE:K-562        23826 non-null  float64
#  26  LE:MOLT-4       23826 non-null  float64
#  27  LE:RPMI-8226    23826 non-null  float64
#  28  LE:SR           23826 non-null  float64
#  29  ME:LOX IMVI     23826 non-null  float64
#  30  ME:MALME-3M     23826 non-null  float64
#  31  ME:M14          23826 non-null  float64
#  32  ME:SK-MEL-2     23826 non-null  float64
#  33  ME:SK-MEL-28    23826 non-null  float64
#  34  ME:SK-MEL-5     23826 non-null  float64
#  35  ME:UACC-257     23826 non-null  float64
#  36  ME:UACC-62      23826 non-null  float64
#  37  ME:MDA-MB-435   23826 non-null  float64
#  38  ME:MDA-N        23826 non-null  float64
#  39  LC:A549/ATCC    23826 non-null  float64
#  40  LC:EKVX         23826 non-null  float64
#  41  LC:HOP-62       23826 non-null  float64
#  42  LC:HOP-92       23826 non-null  float64
#  43  LC:NCI-H226     23826 non-null  float64
#  44  LC:NCI-H23      23826 non-null  float64
#  45  LC:NCI-H322M    23826 non-null  float64
#  46  LC:NCI-H460     23826 non-null  float64
#  47  LC:NCI-H522     23826 non-null  float64
#  48  OV:IGROV1       23826 non-null  float64
#  49  OV:OVCAR-3      23826 non-null  float64
#  50  OV:OVCAR-4      23826 non-null  float64
#  51  OV:OVCAR-5      23826 non-null  float64
#  52  OV:OVCAR-8      23826 non-null  float64
#  53  OV:SK-OV-3      23826 non-null  float64
#  54  OV:NCI/ADR-RES  23826 non-null  float64
#  55  PR:PC-3         23826 non-null  float64
#  56  PR:DU-145       23826 non-null  float64
#  57  RE:786-0        23826 non-null  float64
#  58  RE:A498         23826 non-null  float64
#  59  RE:ACHN         23826 non-null  float64
#  60  RE:CAKI-1       23826 non-null  float64
#  61  RE:RXF 393      23826 non-null  float64
#  62  RE:SN12C        23826 non-null  float64
#  63  RE:TK-10        23826 non-null  float64
#  64  RE:UO-31        23826 non-null  float64
# dtypes: float64(61), int64(2), object(2)
# memory usage: 11.8+ MB
# None
#              ID   chr  txStart   txEnd  entrez.gene.id   BR:MCF7  \
# 0         OR4F5  chr1    69090   70008         79501.0  0.000000
# 1       FAM138A  chr1    34610   36081        645520.0  0.000000
# 2     LOC729737  chr1   134772  140566        729737.0  1.303062
# 3        OR4F29  chr1   367658  368597        729759.0  0.000000
# 4  LOC100132062  chr1   323891  328581     100132062.0  0.150523
#
#    BR:MDA-MB-231  BR:HS 578T  BR:BT-549  BR:T-47D  ...   PR:PC-3  PR:DU-145  \
# 0       0.000000    0.147335   0.000000  0.000000  ...  0.000000   0.000000
# 1       0.000000    0.157361   0.000000  0.000000  ...  0.222157   0.000000
# 2       0.541587    0.262425   0.456917  2.124371  ...  0.623149   1.688328
# 3       0.128686    0.223938   0.000000  0.000000  ...  0.000000   0.000000
# 4       0.000000    0.217617   0.467340  1.150651  ...  0.140081   1.041194
#
#    RE:786-0   RE:A498   RE:ACHN  RE:CAKI-1  RE:RXF 393  RE:SN12C  RE:TK-10  \
# 0  0.000000  0.000000  0.262618   0.000000    0.000000  0.000000  0.000000
# 1  0.000000  0.075905  0.220937   0.000000    0.000000  0.000000  0.000000
# 2  0.463974  0.880185  1.132215   0.429592    0.845533  0.696565  0.669736
# 3  0.150302  0.000000  0.198141   0.000000    0.122993  0.000000  0.000000
# 4  0.409830  0.389207  0.725685   0.211502    0.552284  0.997277  0.322005
#
#    RE:UO-31
# 0  0.000000
# 1  0.000000
# 2  0.598753
# 3  0.000000
# 4  0.114750
#
# [5 rows x 65 columns]

# %%
# Read the microRNA expression: data_NCI-60_mir.txt file

import pandas as pd

# Path to your text file
txt_file_path = "/nfs/turbo/med-kayvan-lab/Projects/DrugCombination/b-DrugCombination/DC_Data/NCI60-microRNA/data_NCI-60_mir.txt"

# Read the text file into a DataFrame
df = pd.read_csv(txt_file_path, delimiter='\t')

# Display the DataFrame
print(df.info())
print(df.head())
# print(df.tail())

# Save the DataFrame to a new CSV file
df.to_csv("NCI60_microRNAExpression.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 71 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Probe id           417 non-null    object
#  1   Gene name          0 non-null      float64
#  2   Entrez gene id     0 non-null      float64
#  3   Chromosome         417 non-null    object
#  4   Start              417 non-null    int64
#  5   End                417 non-null    int64
#  6   Cytoband           0 non-null      float64
#  7   RefSeq(mRNA)       0 non-null      float64
#  8   RefSeq(protein)    0 non-null      float64
#  9   miRNA Accession #  417 non-null    object
#  10  MirBase Name       417 non-null    object
#  11  BR:MCF7            417 non-null    float64
#  12  BR:MDA-MB-231      416 non-null    float64
#  13  BR:HS 578T         417 non-null    float64
#  14  BR:BT-549          417 non-null    float64
#  15  BR:T-47D           417 non-null    float64
#  16  CNS:SF-268         417 non-null    float64
#  17  CNS:SF-295         417 non-null    float64
#  18  CNS:SF-539         417 non-null    float64
#  19  CNS:SNB-19         416 non-null    float64
#  20  CNS:SNB-75         417 non-null    float64
#  21  CNS:U251           417 non-null    float64
#  22  CO:COLO 205        417 non-null    float64
#  23  CO:HCC-2998        417 non-null    float64
#  24  CO:HCT-116         417 non-null    float64
#  25  CO:HCT-15          417 non-null    float64
#  26  CO:HT29            417 non-null    float64
#  27  CO:KM12            417 non-null    float64
#  28  CO:SW-620          417 non-null    float64
#  29  LE:CCRF-CEM        416 non-null    float64
#  30  LE:HL-60(TB)       417 non-null    float64
#  31  LE:K-562           417 non-null    float64
#  32  LE:MOLT-4          417 non-null    float64
#  33  LE:RPMI-8226       416 non-null    float64
#  34  LE:SR              415 non-null    float64
#  35  ME:LOX IMVI        416 non-null    float64
#  36  ME:MALME-3M        417 non-null    float64
#  37  ME:M14             417 non-null    float64
#  38  ME:SK-MEL-2        417 non-null    float64
#  39  ME:SK-MEL-28       417 non-null    float64
#  40  ME:SK-MEL-5        417 non-null    float64
#  41  ME:UACC-257        417 non-null    float64
#  42  ME:UACC-62         417 non-null    float64
#  43  ME:MDA-MB-435      417 non-null    float64
#  44  ME:MDA-N           417 non-null    float64
#  45  LC:A549/ATCC       417 non-null    float64
#  46  LC:EKVX            417 non-null    float64
#  47  LC:HOP-62          417 non-null    float64
#  48  LC:HOP-92          417 non-null    float64
#  49  LC:NCI-H226        417 non-null    float64
#  50  LC:NCI-H23         417 non-null    float64
#  51  LC:NCI-H322M       417 non-null    float64
#  52  LC:NCI-H460        417 non-null    float64
#  53  LC:NCI-H522        417 non-null    float64
#  54  OV:IGROV1          417 non-null    float64
#  55  OV:OVCAR-3         417 non-null    float64
#  56  OV:OVCAR-4         417 non-null    float64
#  57  OV:OVCAR-5         417 non-null    float64
#  58  OV:OVCAR-8         417 non-null    float64
#  59  OV:SK-OV-3         417 non-null    float64
#  60  OV:NCI/ADR-RES     416 non-null    float64
#  61  PR:PC-3            417 non-null    float64
#  62  PR:DU-145          417 non-null    float64
#  63  RE:786-0           417 non-null    float64
#  64  RE:A498            417 non-null    float64
#  65  RE:ACHN            417 non-null    float64
#  66  RE:CAKI-1          417 non-null    float64
#  67  RE:RXF 393         417 non-null    float64
#  68  RE:SN12C           417 non-null    float64
#  69  RE:TK-10           417 non-null    float64
#  70  RE:UO-31           417 non-null    float64
# dtypes: float64(65), int64(2), object(4)
# memory usage: 231.4+ KB
# None
#         Probe id  Gene name  Entrez gene id Chromosome    Start      End  \
# 0   hsa-miR-200b        NaN             NaN          1  1102484  1102578
# 1  hsa-miR-200b*        NaN             NaN          1  1102484  1102578
# 2   hsa-miR-200a        NaN             NaN          1  1103243  1103332
# 3  hsa-miR-200a*        NaN             NaN          1  1103243  1103332
# 4    hsa-miR-429        NaN             NaN          1  1104385  1104467
#
#    Cytoband  RefSeq(mRNA)  RefSeq(protein) miRNA Accession #  ... PR:PC-3  \
# 0       NaN           NaN              NaN         MI0000342  ...   1.361
# 1       NaN           NaN              NaN         MI0000342  ...  -3.366
# 2       NaN           NaN              NaN         MI0000737  ...  -0.471
# 3       NaN           NaN              NaN         MI0000737  ...  -3.366
# 4       NaN           NaN              NaN         MI0001641  ...  -0.851
#
#    PR:DU-145  RE:786-0  RE:A498  RE:ACHN  RE:CAKI-1  RE:RXF 393  RE:SN12C  \
# 0      2.450     3.610    1.974    2.159      2.183       3.893    -4.549
# 1     -3.412    -2.486   -2.894   -3.255     -3.599      -1.673    -4.549
# 2      1.973     1.434   -0.286    1.723      1.343       1.899    -4.549
# 3     -4.032    -2.749   -2.894   -3.705     -4.132      -2.187    -4.549
# 4      0.408     2.035   -0.658   -0.598     -0.063       1.738    -4.549
#
#    RE:TK-10  RE:UO-31
# 0     3.405     3.110
# 1    -2.478    -2.733
# 2     1.343     2.573
# 3    -2.650    -3.324
# 4     1.079     1.068
#
# [5 rows x 71 columns]

# %%
# Read the Protein abundance: data_NCI-60_swa.txt file

import pandas as pd
import numpy as np

# Path to your text file
txt_file_path = "/nfs/turbo/med-kayvan-lab/Projects/DrugCombination/b-DrugCombination/DC_Data/NCI60-Protein/data_NCI-60_swa.txt"

# Read the text file into a DataFrame
df = pd.read_csv(txt_file_path, delimiter='\t')

# Apply log2(x+1) transformation to columns from 11th column to last column
df.iloc[:, 10:] = df.iloc[:, 10:].apply(lambda x: np.log2(x + 1))

# Display the DataFrame
print(df.info())
print(df.head())

# Save the DataFrame to a new CSV file
df.to_csv("NCI60_ProteinAbundance_Log2Transformed.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3167 entries, 0 to 3166
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              3167 non-null   object
#  1   probe_nm        3167 non-null   object
#  2   uniprot_id      3167 non-null   object
#  3   Gene_name       3167 non-null   object
#  4   Entrez_gene     3167 non-null   int64
#  5   Chromosome      3167 non-null   object
#  6   Start_pos       3167 non-null   int64
#  7   End_pos         3167 non-null   int64
#  8   Cytoband        3167 non-null   object
#  9   M_score         3167 non-null   float64
#  10  BR:MCF7         3167 non-null   float64
#  11  BR:MDA-MB-231   3167 non-null   float64
#  12  BR:HS 578T      3167 non-null   float64
#  13  BR:BT-549       3167 non-null   float64
#  14  BR:T-47D        3167 non-null   float64
#  15  CNS:SF-268      3167 non-null   float64
#  16  CNS:SF-295      3167 non-null   float64
#  17  CNS:SF-539      3167 non-null   float64
#  18  CNS:SNB-19      3167 non-null   float64
#  19  CNS:SNB-75      3167 non-null   float64
#  20  CNS:U251        3167 non-null   float64
#  21  CO:COLO 205     3167 non-null   float64
#  22  CO:HCC-2998     3167 non-null   float64
#  23  CO:HCT-116      3167 non-null   float64
#  24  CO:HCT-15       3167 non-null   float64
#  25  CO:HT29         3167 non-null   float64
#  26  CO:KM12         3167 non-null   float64
#  27  CO:SW-620       3167 non-null   float64
#  28  LE:CCRF-CEM     3167 non-null   float64
#  29  LE:HL-60(TB)    3167 non-null   float64
#  30  LE:K-562        3167 non-null   float64
#  31  LE:MOLT-4       3167 non-null   float64
#  32  LE:RPMI-8226    3167 non-null   float64
#  33  LE:SR           3167 non-null   float64
#  34  ME:LOX IMVI     3167 non-null   float64
#  35  ME:MALME-3M     3167 non-null   float64
#  36  ME:M14          3167 non-null   float64
#  37  ME:SK-MEL-2     3167 non-null   float64
#  38  ME:SK-MEL-28    3167 non-null   float64
#  39  ME:SK-MEL-5     3167 non-null   float64
#  40  ME:UACC-257     3167 non-null   float64
#  41  ME:UACC-62      3167 non-null   float64
#  42  ME:MDA-MB-435   3167 non-null   float64
#  43  ME:MDA-N        0 non-null      float64
#  44  LC:A549/ATCC    3167 non-null   float64
#  45  LC:EKVX         3167 non-null   float64
#  46  LC:HOP-62       3167 non-null   float64
#  47  LC:HOP-92       3167 non-null   float64
#  48  LC:NCI-H226     3167 non-null   float64
#  49  LC:NCI-H23      3167 non-null   float64
#  50  LC:NCI-H322M    3167 non-null   float64
#  51  LC:NCI-H460     3167 non-null   float64
#  52  LC:NCI-H522     3167 non-null   float64
#  53  OV:IGROV1       3167 non-null   float64
#  54  OV:OVCAR-3      3167 non-null   float64
#  55  OV:OVCAR-4      3167 non-null   float64
#  56  OV:OVCAR-5      3167 non-null   float64
#  57  OV:OVCAR-8      3167 non-null   float64
#  58  OV:SK-OV-3      3167 non-null   float64
#  59  OV:NCI/ADR-RES  3167 non-null   float64
#  60  PR:PC-3         3167 non-null   float64
#  61  PR:DU-145       3167 non-null   float64
#  62  RE:786-0        3167 non-null   float64
#  63  RE:A498         3167 non-null   float64
#  64  RE:ACHN         3167 non-null   float64
#  65  RE:CAKI-1       3167 non-null   float64
#  66  RE:RXF 393      3167 non-null   float64
#  67  RE:SN12C        3167 non-null   float64
#  68  RE:TK-10        3167 non-null   float64
#  69  RE:UO-31        3167 non-null   float64
# dtypes: float64(61), int64(3), object(6)
# memory usage: 1.7+ MB
# None
#       ID                          probe_nm uniprot_id Gene_name  Entrez_gene  \
# 0  PYCR1      10039_C(UniMod:4)MTNTPVVVR_2     P32322     PYCR1         5831
# 1  SNRPF        10065_C(UniMod:4)NNVLYIR_2     P62306     SNRPF         6636
# 2   TNS3  10084_C(UniMod:4)PADNPGLVQAQPR_2     Q68CZ2      TNS3        64759
# 3  GFPT1     10203_C(UniMod:4)QNALQQVVAR_2     Q06210     GFPT1         2673
# 4   YKT6              1021_AAYDVSSFSFFQR_2     O15498      YKT6        10652
#
#   Chromosome  Start_pos   End_pos Cytoband       M_score  ...   PR:PC-3  \
# 0         17   79890261  79895204  17q25.3  4.100000e-08  ...  2.624569
# 1         12   96252708  96260238  12q23.1  1.730000e-08  ...  2.813114
# 2          7   47314751  47621742   7p12.3  4.630000e-07  ...  2.376290
# 3          2   69546900  69614386     2p13  3.960000e-09  ...  2.615416
# 4          7   44240577  44253893   7p15.1  2.500000e-05  ...  2.638306
#
#    PR:DU-145  RE:786-0   RE:A498   RE:ACHN  RE:CAKI-1  RE:RXF 393  RE:SN12C  \
# 0   2.619178  2.677621  2.672652  2.587125   2.723559    2.543991  2.610936
# 1   2.793688  2.769772  2.746958  2.774629   2.762774    2.783666  2.795975
# 2   2.131260  2.412782  2.491083  2.451805   2.440686    2.402722  2.466236
# 3   2.624569  2.616122  2.656496  2.626439   2.639464    2.616358  2.592876
# 4   2.633664  2.709732  2.695326  2.681674   2.682124    2.543248  2.711715
#
#    RE:TK-10  RE:UO-31
# 0  2.650535  2.575070
# 1  2.798258  2.772308
# 2  2.425459  2.448637
# 3  2.638074  2.627607
# 4  2.543248  2.666529
#
# [5 rows x 70 columns]

# %%
# Concatenate three dataframes, make it as "60CellLinesDescriptor.csv"

import pandas as pd

# Load the three dataframes
gene_expression_df = pd.read_csv("NCI60_GeneExpression.csv")
microRNA_expression_df = pd.read_csv("NCI60_microRNAExpression.csv")
protein_abundance_df = pd.read_csv("NCI60_ProteinAbundance_Log2Transformed.csv")

# Rename the non cell line column names:
for i in range(5):
    gene_expression_df = gene_expression_df.rename(columns={gene_expression_df.columns[i]: f"GeneExp_{gene_expression_df.columns[i]}"})

for i in range(11):
    microRNA_expression_df = microRNA_expression_df.rename(columns={microRNA_expression_df.columns[i]: f"microRNAExp_{microRNA_expression_df.columns[i]}"})

for i in range(10):
    protein_abundance_df = protein_abundance_df.rename(columns={protein_abundance_df.columns[i]: f"ProteinExp_{protein_abundance_df.columns[i]}"})

# Concatenate the dataframes vertically
concatenated_df = pd.concat([gene_expression_df, microRNA_expression_df, protein_abundance_df], join='outer', ignore_index=True)

# Move columns between 6th and 65th to the end
columns_to_move = concatenated_df.columns[5:65]
columns_to_move_df = concatenated_df[columns_to_move]
concatenated_df = concatenated_df.drop(columns_to_move, axis=1)
concatenated_df = pd.concat([concatenated_df, columns_to_move_df], axis=1)

# Display information about the concatenated dataframe
print(concatenated_df.info())

# Save the dataframe to a new CSV file
concatenated_df.to_csv("60CellLinesDescriptor.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27410 entries, 0 to 27409
# Data columns (total 86 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   GeneExp_ID                     23826 non-null  object
#  1   GeneExp_chr                    23826 non-null  object
#  2   GeneExp_txStart                23826 non-null  float64
#  3   GeneExp_txEnd                  23826 non-null  float64
#  4   GeneExp_entrez.gene.id         23804 non-null  float64
#  5   microRNAExp_Probe id           417 non-null    object
#  6   microRNAExp_Gene name          0 non-null      float64
#  7   microRNAExp_Entrez gene id     0 non-null      float64
#  8   microRNAExp_Chromosome         417 non-null    object
#  9   microRNAExp_Start              417 non-null    float64
#  10  microRNAExp_End                417 non-null    float64
#  11  microRNAExp_Cytoband           0 non-null      float64
#  12  microRNAExp_RefSeq(mRNA)       0 non-null      float64
#  13  microRNAExp_RefSeq(protein)    0 non-null      float64
#  14  microRNAExp_miRNA Accession #  417 non-null    object
#  15  microRNAExp_MirBase Name       417 non-null    object
#  16  ProteinExp_ID                  3167 non-null   object
#  17  ProteinExp_probe_nm            3167 non-null   object
#  18  ProteinExp_uniprot_id          3167 non-null   object
#  19  ProteinExp_Gene_name           3167 non-null   object
#  20  ProteinExp_Entrez_gene         3167 non-null   float64
#  21  ProteinExp_Chromosome          3167 non-null   object
#  22  ProteinExp_Start_pos           3167 non-null   float64
#  23  ProteinExp_End_pos             3167 non-null   float64
#  24  ProteinExp_Cytoband            3167 non-null   object
#  25  ProteinExp_M_score             3167 non-null   float64
#  26  BR:MCF7                        27410 non-null  float64
#  27  BR:MDA-MB-231                  27409 non-null  float64
#  28  BR:HS 578T                     27410 non-null  float64
#  29  BR:BT-549                      27410 non-null  float64
#  30  BR:T-47D                       27410 non-null  float64
#  31  CNS:SF-268                     27410 non-null  float64
#  32  CNS:SF-295                     27410 non-null  float64
#  33  CNS:SF-539                     27410 non-null  float64
#  34  CNS:SNB-19                     27409 non-null  float64
#  35  CNS:SNB-75                     27410 non-null  float64
#  36  CNS:U251                       27410 non-null  float64
#  37  CO:COLO 205                    27410 non-null  float64
#  38  CO:HCC-2998                    27410 non-null  float64
#  39  CO:HCT-116                     27410 non-null  float64
#  40  CO:HCT-15                      27410 non-null  float64
#  41  CO:HT29                        27410 non-null  float64
#  42  CO:KM12                        27410 non-null  float64
#  43  CO:SW-620                      27410 non-null  float64
#  44  LE:CCRF-CEM                    27409 non-null  float64
#  45  LE:HL-60(TB)                   27410 non-null  float64
#  46  LE:K-562                       27410 non-null  float64
#  47  LE:MOLT-4                      27410 non-null  float64
#  48  LE:RPMI-8226                   27409 non-null  float64
#  49  LE:SR                          27408 non-null  float64
#  50  ME:LOX IMVI                    27409 non-null  float64
#  51  ME:MALME-3M                    27410 non-null  float64
#  52  ME:M14                         27410 non-null  float64
#  53  ME:SK-MEL-2                    27410 non-null  float64
#  54  ME:SK-MEL-28                   27410 non-null  float64
#  55  ME:SK-MEL-5                    27410 non-null  float64
#  56  ME:UACC-257                    27410 non-null  float64
#  57  ME:UACC-62                     27410 non-null  float64
#  58  ME:MDA-MB-435                  27410 non-null  float64
#  59  ME:MDA-N                       24243 non-null  float64
#  60  LC:A549/ATCC                   27410 non-null  float64
#  61  LC:EKVX                        27410 non-null  float64
#  62  LC:HOP-62                      27410 non-null  float64
#  63  LC:HOP-92                      27410 non-null  float64
#  64  LC:NCI-H226                    27410 non-null  float64
#  65  LC:NCI-H23                     27410 non-null  float64
#  66  LC:NCI-H322M                   27410 non-null  float64
#  67  LC:NCI-H460                    27410 non-null  float64
#  68  LC:NCI-H522                    27410 non-null  float64
#  69  OV:IGROV1                      27410 non-null  float64
#  70  OV:OVCAR-3                     27410 non-null  float64
#  71  OV:OVCAR-4                     27410 non-null  float64
#  72  OV:OVCAR-5                     27410 non-null  float64
#  73  OV:OVCAR-8                     27410 non-null  float64
#  74  OV:SK-OV-3                     27410 non-null  float64
#  75  OV:NCI/ADR-RES                 27409 non-null  float64
#  76  PR:PC-3                        27410 non-null  float64
#  77  PR:DU-145                      27410 non-null  float64
#  78  RE:786-0                       27410 non-null  float64
#  79  RE:A498                        27410 non-null  float64
#  80  RE:ACHN                        27410 non-null  float64
#  81  RE:CAKI-1                      27410 non-null  float64
#  82  RE:RXF 393                     27410 non-null  float64
#  83  RE:SN12C                       27410 non-null  float64
#  84  RE:TK-10                       27410 non-null  float64
#  85  RE:UO-31                       27410 non-null  float64
# dtypes: float64(74), object(12)
# memory usage: 18.0+ MB
# None
